# %%
import boto3
import os
import sagemaker
import tensorflow as tf

sess = sagemaker.session.Session()
bucket = sess.default_bucket() 
region = boto3.Session().region_name

data_dir = os.path.join(os.getcwd(), 'data')
os.makedirs(data_dir, exist_ok=True)

train_dir = os.path.join(os.getcwd(), 'data/train')
os.makedirs(train_dir, exist_ok=True)

test_dir = os.path.join(os.getcwd(), 'data/test')
os.makedirs(test_dir, exist_ok=True)

raw_dir = os.path.join(os.getcwd(), 'data/raw')
os.makedirs(raw_dir, exist_ok=True)

batch_dir = os.path.join(os.getcwd(), 'data/batch')
os.makedirs(batch_dir, exist_ok=True)

# %%
# SageMaker Processing for dataset transformation
# Saving raw data to S3

import numpy as np
from tensorflow.python.keras.datasets import boston_housing
from sklearn.preprocessing import StandardScaler

(x_train, y_train), (x_test, y_test) = boston_housing.load_data()

np.save(os.path.join(raw_dir, 'x_train.npy'), x_train)
np.save(os.path.join(raw_dir, 'x_test.npy'), x_test)
np.save(os.path.join(raw_dir, 'y_train.npy'), y_train)
np.save(os.path.join(raw_dir, 'y_test.npy'), y_test)
s3_prefix = 'tf-2-workflow'
rawdata_s3_prefix = '{}/data/raw'.format(s3_prefix)
raw_s3 = sess.upload_data(path='./data/raw/', key_prefix=rawdata_s3_prefix)
print(raw_s3)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/boston_housing.npz
# 57344/57026 [==============================] - 0s 0us/step
# s3://sagemaker-us-west-2-867719205611/tf-2-workflow/data/raw

# %%
from sagemaker import get_execution_role
from sagemaker.sklearn.processing import SKLearnProcessor

sklearn_processor1 = SKLearnProcessor(framework_version='0.23-1',
                                     role=get_execution_role(),
                                     instance_type='ml.m5.xlarge',
                                     instance_count=2)

# %%
from sagemaker.processing import ProcessingInput, ProcessingOutput
from time import gmtime, strftime 

processing_job_name = "tf-2-workflow-{}".format(strftime("%d-%H-%M-%S", gmtime()))
output_destination = 's3://{}/{}/data'.format(bucket, s3_prefix)

sklearn_processor1.run(code='preprocessing.py',
                      job_name=processing_job_name,
                      inputs=[ProcessingInput(
                        source=raw_s3,
                        destination='/opt/ml/processing/input',
                        s3_data_distribution_type='ShardedByS3Key')],
                      outputs=[ProcessingOutput(output_name='train',
                                                destination='{}/train'.format(output_destination),
                                                source='/opt/ml/processing/train'),
                               ProcessingOutput(output_name='test',
                                                destination='{}/test'.format(output_destination),
                                                source='/opt/ml/processing/test')])

preprocessing_job_description = sklearn_processor1.jobs[-1].describe()
# Out:
# Job Name:  tf-2-workflow-16-04-59-22
# Inputs:  [{'InputName': 'input-1', 'S3Input': {'S3Uri': 's3://sagemaker-us-west-2-867719205611/tf-2-workflow/data/raw', 'LocalPath': '/opt/ml/processing/input', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3DataDistributionType': 'ShardedByS3Key', 'S3CompressionType': 'None'}}, {'InputName': 'code', 'S3Input': {'S3Uri': 's3://sagemaker-us-west-2-867719205611/tf-2-workflow-16-04-59-22/input/code/preprocessing.py', 'LocalPath': '/opt/ml/processing/input/code', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3DataDistributionType': 'FullyReplicated', 'S3CompressionType': 'None'}}]
# Outputs:  [{'OutputName': 'train', 'S3Output': {'S3Uri': 's3://sagemaker-us-west-2-867719205611/tf-2-workflow/data/train', 'LocalPath': '/opt/ml/processing/train', 'S3UploadMode': 'EndOfJob'}}, {'OutputName': 'test', 'S3Output': {'S3Uri': 's3://sagemaker-us-west-2-867719205611/tf-2-workflow/data/test', 'LocalPath': '/opt/ml/processing/test', 'S3UploadMode': 'EndOfJob'}}]
# .........................INPUT FILE LIST:
# ['/opt/ml/processing/input/x_train.npy', '/opt/ml/processing/input/y_train.npy']
#
# SAVED TRANSFORMED TRAINING DATA FILE
#
# SAVED LABEL TRAINING DATA FILE
#
# INPUT FILE LIST:
# ['/opt/ml/processing/input/y_test.npy', '/opt/ml/processing/input/x_test.npy']
#
# SAVED LABEL TEST DATA FILE
#
# SAVED TRANSFORMED TEST DATA FILE

# %%
x_train_in_s3 = '{}/train/x_train.npy'.format(output_destination)
y_train_in_s3 = '{}/train/y_train.npy'.format(output_destination)
x_test_in_s3 = '{}/test/x_test.npy'.format(output_destination)
y_test_in_s3 = '{}/test/y_test.npy'.format(output_destination)

# !aws s3 cp {x_train_in_s3} ./data/train/x_train.npy
# !aws s3 cp {y_train_in_s3} ./data/train/y_train.npy
# !aws s3 cp {x_test_in_s3} ./data/test/x_test.npy
# !aws s3 cp {y_test_in_s3} ./data/test/y_test.npy
# Out:
# download: s3://sagemaker-us-west-2-867719205611/tf-2-workflow/data/train/x_train.npy to data/train/x_train.npy
# download: s3://sagemaker-us-west-2-867719205611/tf-2-workflow/data/train/y_train.npy to data/train/y_train.npy
# download: s3://sagemaker-us-west-2-867719205611/tf-2-workflow/data/test/x_test.npy to data/test/x_test.npy
# download: s3://sagemaker-us-west-2-867719205611/tf-2-workflow/data/test/y_test.npy to data/test/y_test.npy

# %%
# Training!!!

s3_prefix = 'tf-2-workflow'

traindata_s3_prefix = '{}/data/train'.format(s3_prefix)
testdata_s3_prefix = '{}/data/test'.format(s3_prefix)

# %%
# upload train and validation dataset to s3

train_s3 = sess.upload_data(path='./data/train/', key_prefix=traindata_s3_prefix)
test_s3 = sess.upload_data(path='./data/test/', key_prefix=testdata_s3_prefix)

inputs = {'train':train_s3, 'test': test_s3}

print(inputs)
# Out:
# {'train': 's3://sagemaker-us-west-2-867719205611/tf-2-workflow/data/train', 'test': 's3://sagemaker-us-west-2-867719205611/tf-2-workflow/data/test'}

# %%
# Set up an tensorflow estimator object

from sagemaker.tensorflow import TensorFlow

train_instance_type = 'ml.c5.xlarge'
hyperparameters = {'epochs': 30, 'batch_size': 128, 'learning_rate': 0.01}

git_config = {'repo': 'https://github.com/aws-samples/amazon-sagemaker-script-mode', 
              'branch': 'master'}

hosted_estimator = TensorFlow(
                       git_config=git_config,
                       source_dir='tf-2-workflow-smpipelines/train_model',
                       entry_point='train.py',
                       instance_type=train_instance_type,
                       instance_count=1,
                       hyperparameters=hyperparameters,
                       role=sagemaker.get_execution_role(),
                       base_job_name='tf-2-workflow',
                       framework_version='2.3.1',
                       py_version='py37',
                       script_mode=True)

# %%
# Fitting the model

hosted_estimator.fit(inputs)
# Out:
# 2021-01-16 05:09:52 Starting - Starting the training job...
# 2021-01-16 05:10:16 Starting - Launching requested ML instancesProfilerReport-1610773791: InProgress
# ......
# 2021-01-16 05:11:16 Starting - Preparing the instances for training...
# 2021-01-16 05:11:50 Downloading - Downloading input data...
# 2021-01-16 05:12:17 Training - Downloading the training image..2021-01-16 05:12:31.082142: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2021-01-16 05:12:31.087389: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# 2021-01-16 05:12:31.273543: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2021-01-16 05:12:34,102 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 2021-01-16 05:12:34,109 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-01-16 05:12:37,461 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-01-16 05:12:37,476 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-01-16 05:12:37,492 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-01-16 05:12:37,501 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "test": "/opt/ml/input/data/test",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "batch_size": 128,
#         "model_dir": "s3://sagemaker-us-west-2-867719205611/tf-2-workflow-2021-01-16-05-09-51-399/model",
#         "epochs": 30,
#         "learning_rate": 0.01
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "test": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "tf-2-workflow-2021-01-16-05-09-51-399",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-west-2-867719205611/tf-2-workflow-2021-01-16-05-09-51-399/source/sourcedir.tar.gz",
#     "module_name": "train",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch_size":128,"epochs":30,"learning_rate":0.01,"model_dir":"s3://sagemaker-us-west-2-867719205611/tf-2-workflow-2021-01-16-05-09-51-399/model"}
# SM_USER_ENTRY_POINT=train.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["test","train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-west-2-867719205611/tf-2-workflow-2021-01-16-05-09-51-399/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"test":"/opt/ml/input/data/test","train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1"],"hyperparameters":{"batch_size":128,"epochs":30,"learning_rate":0.01,"model_dir":"s3://sagemaker-us-west-2-867719205611/tf-2-workflow-2021-01-16-05-09-51-399/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"tf-2-workflow-2021-01-16-05-09-51-399","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-west-2-867719205611/tf-2-workflow-2021-01-16-05-09-51-399/source/sourcedir.tar.gz","module_name":"train","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train.py"}
# SM_USER_ARGS=["--batch_size","128","--epochs","30","--learning_rate","0.01","--model_dir","s3://sagemaker-us-west-2-867719205611/tf-2-workflow-2021-01-16-05-09-51-399/model"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TEST=/opt/ml/input/data/test
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_BATCH_SIZE=128
# SM_HP_MODEL_DIR=s3://sagemaker-us-west-2-867719205611/tf-2-workflow-2021-01-16-05-09-51-399/model
# SM_HP_EPOCHS=30
# SM_HP_LEARNING_RATE=0.01
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python37.zip:/usr/local/lib/python3.7:/usr/local/lib/python3.7/lib-dynload:/usr/local/lib/python3.7/site-packages
#
# Invoking script with the following command:
#
# /usr/local/bin/python3.7 train.py --batch_size 128 --epochs 30 --learning_rate 0.01 --model_dir s3://sagemaker-us-west-2-867719205611/tf-2-workflow-2021-01-16-05-09-51-399/model
#
#
# Training data location: /opt/ml/input/data/train
# Test data location: /opt/ml/input/data/test
# x train (404, 13) y train (404,)
# x test (102, 13) y test (102,)
# /cpu:0
# batch_size = 128, epochs = 30, learning rate = 0.01
# [2021-01-16 05:12:39.241 ip-10-0-224-156.us-west-2.compute.internal:24 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2021-01-16 05:12:39.449 ip-10-0-224-156.us-west-2.compute.internal:24 INFO profiler_config_parser.py:102] User has disabled profiler.
# [2021-01-16 05:12:39.549 ip-10-0-224-156.us-west-2.compute.internal:24 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2021-01-16 05:12:39.549 ip-10-0-224-156.us-west-2.compute.internal:24 INFO hook.py:199] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2021-01-16 05:12:39.742 ip-10-0-224-156.us-west-2.compute.internal:24 INFO hook.py:253] Saving to /opt/ml/output/tensors
# [2021-01-16 05:12:39.742 ip-10-0-224-156.us-west-2.compute.internal:24 INFO state_store.py:67] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2021-01-16 05:12:39.744 ip-10-0-224-156.us-west-2.compute.internal:24 INFO hook.py:413] Monitoring the collections: metrics, losses, sm_metrics
# Epoch 1/30
# [2021-01-16 05:12:40.229 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.230 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.230 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.230 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# #0151/4 [======>.......................] - ETA: 0s - loss: 518.4800 - batch: 0.0000e+00[2021-01-16 05:12:40.236 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.236 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.236 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.236 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.238 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.238 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.238 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.239 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.241 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.241 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.241 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.241 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.447 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.447 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.447 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.447 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# #010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0154/4 [==============================] - 0s 55ms/step - loss: 481.8944 - batch: 0.0000e+00 - val_loss: 363.8607 - val_batch: 0.0000e+00
# Epoch 2/30
# [2021-01-16 05:12:40.465 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.465 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.465 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.465 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# #0151/4 [======>.......................] - ETA: 0s - loss: 317.2444[2021-01-16 05:12:40.469 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.469 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.469 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.469 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.472 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.472 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.472 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.472 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.477 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.477 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.477 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.477 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.518 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.518 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.518 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.518 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# #010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0154/4 [==============================] - 0s 14ms/step - loss: 295.9326 - val_loss: 198.2716 - batch: 1.0000
# Epoch 3/30
# [2021-01-16 05:12:40.527 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.527 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.527 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.527 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# #0151/4 [======>.......................] - ETA: 0s - loss: 197.7380[2021-01-16 05:12:40.530 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.531 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.531 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.531 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.534 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.534 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.534 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.534 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.537 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.537 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.537 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.537 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.570 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.570 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.570 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.570 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# #010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0154/4 [==============================] - 0s 12ms/step - loss: 158.7540 - val_loss: 111.6654 - batch: 2.0000
# Epoch 4/30
# [2021-01-16 05:12:40.580 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.580 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.580 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.580 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# #0151/4 [======>.......................] - ETA: 0s - loss: 84.0926[2021-01-16 05:12:40.583 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.583 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.583 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.583 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.588 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.588 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.588 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.589 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.591 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.591 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.591 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.591 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.633 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.634 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.634 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.634 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# #010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0154/4 [==============================] - 0s 15ms/step - loss: 95.1980 - val_loss: 73.7489 - batch: 3.0000
# Epoch 5/30
# [2021-01-16 05:12:40.642 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.642 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.642 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.642 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# #0151/4 [======>.......................] - ETA: 0s - loss: 83.0054[2021-01-16 05:12:40.645 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.645 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.645 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.645 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.648 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.648 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.648 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.648 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.651 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.651 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.651 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.651 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.683 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.684 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.684 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.684 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# #010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0154/4 [==============================] - 0s 11ms/step - loss: 69.5156 - val_loss: 59.0742 - batch: 4.0000
# Epoch 6/30
# [2021-01-16 05:12:40.691 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.691 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.691 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.691 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# #0151/4 [======>.......................] - ETA: 0s - loss: 56.7878[2021-01-16 05:12:40.694 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.694 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.694 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.695 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.698 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.698 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.698 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.698 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.703 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.703 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.704 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.704 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.738 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.739 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.739 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.739 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# #010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0154/4 [==============================] - 0s 13ms/step - loss: 59.4161 - val_loss: 51.8213 - batch: 5.0000
# Epoch 7/30
# [2021-01-16 05:12:40.748 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.748 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.748 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.748 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# #0151/4 [======>.......................] - ETA: 0s - loss: 45.8584[2021-01-16 05:12:40.751 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.751 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.752 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.752 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.754 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.754 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.754 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.754 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.756 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.756 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.756 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.756 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.789 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.789 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.790 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.790 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# #010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0154/4 [==============================] - 0s 11ms/step - loss: 54.0146 - val_loss: 47.2755 - batch: 6.0000
# Epoch 8/30
# [2021-01-16 05:12:40.797 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.797 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.797 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.797 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# #0151/4 [======>.......................] - ETA: 0s - loss: 44.5830[2021-01-16 05:12:40.799 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.799 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.800 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.800 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.802 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.802 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.802 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.802 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.804 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.804 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.804 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.804 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.838 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.838 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.838 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.838 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# #010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0154/4 [==============================] - 0s 11ms/step - loss: 50.5555 - val_loss: 45.0202 - batch: 7.0000
# Epoch 9/30
# [2021-01-16 05:12:40.846 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.846 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.846 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.846 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# #0151/4 [======>.......................] - ETA: 0s - loss: 52.2009[2021-01-16 05:12:40.848 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.849 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.849 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.849 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.851 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.851 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.851 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.851 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.853 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.853 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.853 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.853 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.888 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.888 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.888 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.888 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# #010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0154/4 [==============================] - 0s 12ms/step - loss: 48.6860 - val_loss: 43.7770 - batch: 8.0000
# Epoch 10/30
# [2021-01-16 05:12:40.896 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.896 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.896 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.896 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# #0151/4 [======>.......................] - ETA: 0s - loss: 49.8591[2021-01-16 05:12:40.899 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.899 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.899 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.899 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.902 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.902 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.902 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.902 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.904 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.904 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.904 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.904 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.940 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.940 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.940 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.940 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# #010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0154/4 [==============================] - 0s 12ms/step - loss: 46.5069 - val_loss: 42.0122 - batch: 9.0000
# Epoch 11/30
# [2021-01-16 05:12:40.950 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.950 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.950 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.950 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# #0151/4 [======>.......................] - ETA: 0s - loss: 39.8656[2021-01-16 05:12:40.958 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.959 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.959 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.959 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.963 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.963 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.964 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.964 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.967 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.967 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.967 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:40.967 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.001 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.002 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.002 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.002 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# #010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0154/4 [==============================] - 0s 14ms/step - loss: 45.3293 - val_loss: 39.8521 - batch: 10.0000
# Epoch 12/30
# [2021-01-16 05:12:41.008 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.008 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.008 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.008 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# #0151/4 [======>.......................] - ETA: 0s - loss: 50.2931[2021-01-16 05:12:41.012 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.012 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.012 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# ...
# [2021-01-16 05:12:41.836 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.836 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.836 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.836 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.838 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.838 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.838 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.838 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.871 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.871 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.871 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.871 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# #010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0154/4 [==============================] - 0s 11ms/step - loss: 21.9786 - val_loss: 22.5242 - batch: 26.0000
# Epoch 28/30
# [2021-01-16 05:12:41.877 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.877 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.877 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.877 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# #0151/4 [======>.......................] - ETA: 0s - loss: 18.6087[2021-01-16 05:12:41.879 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.880 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.880 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.880 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.882 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.882 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.882 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.882 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.884 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.884 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.884 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.884 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.916 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.916 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.917 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.917 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# #010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0154/4 [==============================] - 0s 11ms/step - loss: 20.6246 - val_loss: 25.1593 - batch: 27.0000
# Epoch 29/30
# [2021-01-16 05:12:41.924 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.924 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.925 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.925 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# #0151/4 [======>.......................] - ETA: 0s - loss: 21.9866[2021-01-16 05:12:41.928 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.928 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.928 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.928 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.937 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.937 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.937 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.937 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.939 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.939 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.939 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.939 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.973 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.973 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.973 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.973 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# #010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0154/4 [==============================] - 0s 13ms/step - loss: 21.6386 - val_loss: 22.1047 - batch: 28.0000
# Epoch 30/30
# [2021-01-16 05:12:41.980 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.980 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.980 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.981 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# #0151/4 [======>.......................] - ETA: 0s - loss: 18.2270[2021-01-16 05:12:41.984 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.984 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.984 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.984 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.990 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.990 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.990 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:41.990 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:42.000 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:42.000 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:42.000 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:42.000 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:42.037 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:42.037 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:42.037 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:42.037 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# #010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0154/4 [==============================] - 0s 15ms/step - loss: 19.4663 - val_loss: 20.6274 - batch: 29.0000
# [2021-01-16 05:12:42.092 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:42.092 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:42.092 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# [2021-01-16 05:12:42.092 ip-10-0-224-156.us-west-2.compute.internal:24 WARNING keras.py:603] cannot save layer values during forward pass with tf.function
# 1/1 - 0s - loss: 20.6274
#
# Test MSE : 20.627422332763672
#
# 2021-01-16 05:12:46 Uploading - Uploading generated training model2021-01-16 05:12:37.805518: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2021-01-16 05:12:37.805650: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# 2021-01-16 05:12:37.832410: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# 2021-01-16 05:12:42.185982: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: /opt/ml/model/1/assets
# INFO:tensorflow:Assets written to: /opt/ml/model/1/assets
#
# 2021-01-16 05:12:42,830 sagemaker-training-toolkit INFO     Reporting training SUCCESS
#
# 2021-01-16 05:13:18 Completed - Training job completed
# Training seconds: 64
# Billable seconds: 64

# %%
# !aws s3 cp {hosted_estimator.model_data} ./model/model.tar.gz
# Out:
# download: s3://sagemaker-us-west-2-867719205611/tf-2-workflow-2021-01-16-05-09-51-399/output/model.tar.gz to model/model.tar.gz

# %%
# !tar -xvzf ./model/model.tar.gz -C ./model
# Out:
# 1/
# 1/variables/
# 1/variables/variables.index
# 1/variables/variables.data-00000-of-00001
# 1/saved_model.pb
# 1/assets/

# %%
# Model tuning

from sagemaker.tuner import IntegerParameter, CategoricalParameter, ContinuousParameter, HyperparameterTuner

hyperparameter_ranges = {
  'learning_rate': ContinuousParameter(0.001, 0.2, scaling_type="Logarithmic"),
  'epochs': IntegerParameter(10, 50),
  'batch_size': IntegerParameter(64, 256),
}

metric_definitions = [{'Name': 'loss',
                       'Regex': ' loss: ([0-9\\.]+)'},
                     {'Name': 'val_loss',
                       'Regex': ' val_loss: ([0-9\\.]+)'}]

objective_metric_name = 'val_loss'
objective_type = 'Minimize'

# %%
tuner = HyperparameterTuner(hosted_estimator,
                            objective_metric_name,
                            hyperparameter_ranges,
                            metric_definitions,
                            max_jobs=15,
                            max_parallel_jobs=5,
                            objective_type=objective_type)

tuning_job_name = "tf-2-workflow-{}".format(strftime("%d-%H-%M-%S", gmtime()))
tuner.fit(inputs, job_name=tuning_job_name)
tuner.wait()
# Out:
# ....................................................................................................................................!
# !

# %%
tuner_metrics = sagemaker.HyperparameterTuningJobAnalytics(tuning_job_name)
tuner_metrics.dataframe().sort_values(['FinalObjectiveValue'], ascending=True).head(5)
# Out:
#     batch_size  epochs  learning_rate                         TrainingJobName  \
# 4        231.0    47.0       0.176477  tf-2-workflow-16-05-20-34-011-1f4a1365
# 6         65.0    47.0       0.006957  tf-2-workflow-16-05-20-34-009-271ee3de
# 10       220.0    46.0       0.087906  tf-2-workflow-16-05-20-34-005-1bfd22f2
# 3        102.0    30.0       0.032157  tf-2-workflow-16-05-20-34-012-c83e1752
# 1        102.0    48.0       0.006711  tf-2-workflow-16-05-20-34-014-2d841776
#
#    TrainingJobStatus  FinalObjectiveValue         TrainingStartTime  \
# 4          Completed            17.095400 2021-01-16 05:28:44+00:00
# 6          Completed            19.587400 2021-01-16 05:25:49+00:00
# 10         Completed            20.577499 2021-01-16 05:23:00+00:00
# 3          Completed            20.900400 2021-01-16 05:28:42+00:00
# 1          Completed            21.050100 2021-01-16 05:29:16+00:00
#
#              TrainingEndTime  TrainingElapsedTimeSeconds
# 4  2021-01-16 05:29:34+00:00                        50.0
# 6  2021-01-16 05:26:57+00:00                        68.0
# 10 2021-01-16 05:24:04+00:00                        64.0
# 3  2021-01-16 05:29:36+00:00                        54.0
# 1  2021-01-16 05:30:09+00:00                        53.0

# %%
total_time = tuner_metrics.dataframe()['TrainingElapsedTimeSeconds'].sum() / 3600
print("The total training time is {:.2f} hours".format(total_time))
tuner_metrics.dataframe()['TrainingJobStatus'].value_counts()
# Out:
# The total training time is 0.24 hours
# Completed    15
# Name: TrainingJobStatus, dtype: int64

# %%
# Deploy the model

tuning_predictor = tuner.deploy(initial_instance_count=1, instance_type='ml.m5.xlarge')
# Out:
# 2021-01-16 05:29:34 Starting - Preparing the instances for training
# 2021-01-16 05:29:34 Downloading - Downloading input data
# 2021-01-16 05:29:34 Training - Training image download completed. Training in progress.
# 2021-01-16 05:29:34 Uploading - Uploading generated training model
# 2021-01-16 05:29:34 Completed - Training job completed
# update_endpoint is a no-op in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# -------------!

# %%
results = tuning_predictor.predict(x_test[:10])['predictions'] 
flat_list = [float('%.1f'%(item)) for sublist in results for item in sublist]
print('predictions: \t{}'.format(np.array(flat_list)))
print('target values: \t{}'.format(y_test[:10].round(decimals=1)))
# Out:
# predictions: 	[18.9 42.9 43.3 42.9 42.9 42.9 31.3 31.3 31.1 42.9]
# target values: 	[ 7.2 18.8 19.  27.  22.2 24.5 31.2 22.9 20.5 23.2]

# %%
sess.delete_endpoint(tuning_predictor.endpoint_name)

# %%
# Sagemaker pipeline setup for automating the workflow

from sagemaker.workflow.parameters import (
    ParameterInteger,
    ParameterString,
)

# raw input data
input_data = ParameterString(name="InputData", default_value=raw_s3)

# processing step parameters
processing_instance_type = ParameterString(name="ProcessingInstanceType", default_value="ml.m5.xlarge")
processing_instance_count = ParameterInteger(name="ProcessingInstanceCount", default_value=2)

# training step parameters
training_instance_type = ParameterString(name="TrainingInstanceType", default_value="ml.c5.2xlarge")
training_instance_count = ParameterInteger(name="TrainingInstanceCount", default_value=1)

# batch inference step parameters
batch_instance_type = ParameterString(name="BatchInstanceType", default_value="ml.c5.xlarge")
batch_instance_count = ParameterInteger(name="BatchInstanceCount", default_value=1)

# %%
from sagemaker.sklearn.processing import SKLearnProcessor

role = sagemaker.get_execution_role()
framework_version = "0.23-1"

sklearn_processor = SKLearnProcessor(
    framework_version=framework_version,
    instance_type=processing_instance_type,
    instance_count=processing_instance_count,
    base_job_name="tf-2-workflow-process",
    sagemaker_session=sess,
    role=role,
)

from sagemaker.processing import ProcessingInput, ProcessingOutput
from sagemaker.workflow.steps import ProcessingStep


step_process = ProcessingStep(
    name="TF2Process",
    processor=sklearn_processor,
    inputs=[
        ProcessingInput(source=input_data, destination="/opt/ml/processing/input", s3_data_distribution_type='ShardedByS3Key'),
    ],
    outputs=[
        ProcessingOutput(output_name="train", source="/opt/ml/processing/train"),
        ProcessingOutput(output_name="test", source="/opt/ml/processing/test"),
    ],
    code="./preprocessing.py",
)

# %%
from sagemaker.tensorflow import TensorFlow
from sagemaker.inputs import TrainingInput
from sagemaker.workflow.steps import TrainingStep
from sagemaker.workflow.step_collections import RegisterModel

tensorflow_version = '2.3.1'
python_version = 'py37'

image_uri_train = sagemaker.image_uris.retrieve(
                                        framework="tensorflow",
                                        region=region,
                                        version=tensorflow_version,
                                        py_version=python_version,
                                        instance_type=training_instance_type,
                                        image_scope="training"
                                       )

import time

model_path = f"s3://{bucket}/TF2WorkflowTrain"
training_parameters = {'epochs': 44, 'batch_size': 128, 'learning_rate': 0.0125, 'for_pipeline': 'true'}

estimator = TensorFlow(
    image_uri=image_uri_train,
    git_config=git_config,
    source_dir='tf-2-workflow-smpipelines/train_model',
    entry_point='train.py',
    instance_type=training_instance_type,
    instance_count=training_instance_count,
    role=role,
    base_job_name="tf-2-workflow-train",
    output_path=model_path,
    hyperparameters=training_parameters
)

# %%
step_train = TrainingStep(
    name="TF2WorkflowTrain",
    estimator=estimator,
    inputs={
        "train": TrainingInput(
            s3_data=step_process.properties.ProcessingOutputConfig.Outputs[
                "train"
            ].S3Output.S3Uri
        ),
        "test": TrainingInput(
            s3_data=step_process.properties.ProcessingOutputConfig.Outputs[
                "test"
            ].S3Output.S3Uri
        )
    },
)

# %%
from sagemaker.model import Model
from sagemaker.inputs import CreateModelInput
from sagemaker.workflow.steps import CreateModelStep

image_uri_inference = sagemaker.image_uris.retrieve(
                                        framework="tensorflow",
                                        region=region,
                                        version=tensorflow_version,
                                        py_version=python_version,
                                        instance_type=batch_instance_type,
                                        image_scope="inference"
                                       )
model = Model(
    image_uri=image_uri_inference,
    model_data=step_train.properties.ModelArtifacts.S3ModelArtifacts,
    sagemaker_session=sess,
    role=role,
)

inputs_model = CreateModelInput(
    instance_type=batch_instance_type
)

step_create_model = CreateModelStep(
    name="TF2WorkflowCreateModel",
    model=model,
    inputs=inputs_model,
)

# %%
batch_scorer = SKLearnProcessor(
                    framework_version=framework_version,
                    instance_type=batch_instance_type,
                    instance_count=batch_instance_count,
                    base_job_name="tf-2-workflow-batch",
                    sagemaker_session=sess,
                    role=role )

step_batch = ProcessingStep(
                    name="TF2WorkflowBatchScoring",
                    processor=batch_scorer,
                    inputs=[
                        ProcessingInput(
                            source=step_train.properties.ModelArtifacts.S3ModelArtifacts,
                            destination="/opt/ml/processing/model"
                        ),
                        ProcessingInput(
                            source=step_process.properties.ProcessingOutputConfig.Outputs[
                                "test"
                            ].S3Output.S3Uri,
                            destination="/opt/ml/processing/test"
                        )
                    ],
                    outputs=[
                        ProcessingOutput(output_name="batch", source="/opt/ml/processing/batch"),
                    ],
                    code="./batch-score.py" )

# %%
from sagemaker.workflow.pipeline import Pipeline

pipeline_name = f"TF2Workflow"

pipeline = Pipeline(
    name=pipeline_name,
    parameters=[input_data,
                processing_instance_type, 
                processing_instance_count, 
                training_instance_type, 
                training_instance_count,
                batch_instance_type,
                batch_instance_count],
    steps=[step_process, 
           step_train, 
           step_create_model,
           step_batch
          ],
    sagemaker_session=sess
)

# %%
import json

definition = json.loads(pipeline.definition())
definition
# Out:
# {'Version': '2020-12-01',
#  'Metadata': {},
#  'Parameters': [{'Name': 'InputData',
#    'Type': 'String',
#    'DefaultValue': 's3://sagemaker-us-west-2-867719205611/tf-2-workflow/data/raw'},
#   {'Name': 'ProcessingInstanceType',
#    'Type': 'String',
#    'DefaultValue': 'ml.m5.xlarge'},
#   {'Name': 'ProcessingInstanceCount', 'Type': 'Integer', 'DefaultValue': 2},
#   {'Name': 'TrainingInstanceType',
#    'Type': 'String',
#    'DefaultValue': 'ml.c5.2xlarge'},
#   {'Name': 'TrainingInstanceCount', 'Type': 'Integer', 'DefaultValue': 1},
#   {'Name': 'BatchInstanceType',
#    'Type': 'String',
#    'DefaultValue': 'ml.c5.xlarge'},
#   {'Name': 'BatchInstanceCount', 'Type': 'Integer', 'DefaultValue': 1}],
#  'Steps': [{'Name': 'TF2Process',
#    'Type': 'Processing',
#    'Arguments': {'ProcessingResources': {'ClusterConfig': {'InstanceType': {'Get': 'Parameters.ProcessingInstanceType'},
#       'InstanceCount': {'Get': 'Parameters.ProcessingInstanceCount'},
#       'VolumeSizeInGB': 30}},
#     'AppSpecification': {'ImageUri': '246618743249.dkr.ecr.us-west-2.amazonaws.com/sagemaker-scikit-learn:0.23-1-cpu-py3',
#      'ContainerEntrypoint': ['python3',
#       '/opt/ml/processing/input/code/preprocessing.py']},
#     'RoleArn': 'arn:aws:iam::867719205611:role/service-role/AmazonSageMaker-ExecutionRole-20210115T224947',
#     'ProcessingInputs': [{'InputName': 'input-1',
#       'S3Input': {'S3Uri': {'Get': 'Parameters.InputData'},
#        'LocalPath': '/opt/ml/processing/input',
#        'S3DataType': 'S3Prefix',
#        'S3InputMode': 'File',
#        'S3DataDistributionType': 'ShardedByS3Key',
#        'S3CompressionType': 'None'}},
#      {'InputName': 'code',
#       'S3Input': {'S3Uri': 's3://sagemaker-us-west-2-867719205611/tf-2-workflow-process-2021-01-16-05-51-32-044/input/code/preprocessing.py',
#        'LocalPath': '/opt/ml/processing/input/code',
#        'S3DataType': 'S3Prefix',
#        'S3InputMode': 'File',
#        'S3DataDistributionType': 'FullyReplicated',
#        'S3CompressionType': 'None'}}],
#     'ProcessingOutputConfig': {'Outputs': [{'OutputName': 'train',
#        'S3Output': {'S3Uri': 's3://sagemaker-us-west-2-867719205611/tf-2-workflow-process-2021-01-16-05-51-32-044/output/train',
#         'LocalPath': '/opt/ml/processing/train',
#         'S3UploadMode': 'EndOfJob'}},
#       {'OutputName': 'test',
#        'S3Output': {'S3Uri': 's3://sagemaker-us-west-2-867719205611/tf-2-workflow-process-2021-01-16-05-51-32-044/output/test',
#         'LocalPath': '/opt/ml/processing/test',
#         'S3UploadMode': 'EndOfJob'}}]}}},
#   {'Name': 'TF2WorkflowTrain',
#    'Type': 'Training',
#    'Arguments': {'AlgorithmSpecification': {'TrainingInputMode': 'File',
#      'TrainingImage': '763104351884.dkr.ecr.us-west-2.amazonaws.com/tensorflow-training:2.3.1-cpu-py37'},
#     'OutputDataConfig': {'S3OutputPath': 's3://sagemaker-us-west-2-867719205611/TF2WorkflowTrain'},
#     'StoppingCondition': {'MaxRuntimeInSeconds': 86400},
#     'ResourceConfig': {'InstanceCount': {'Get': 'Parameters.TrainingInstanceCount'},
#      'InstanceType': {'Get': 'Parameters.TrainingInstanceType'},
#      'VolumeSizeInGB': 30},
#     'RoleArn': 'arn:aws:iam::867719205611:role/service-role/AmazonSageMaker-ExecutionRole-20210115T224947',
#     'InputDataConfig': [{'DataSource': {'S3DataSource': {'S3DataType': 'S3Prefix',
#         'S3Uri': {'Get': "Steps.TF2Process.ProcessingOutputConfig.Outputs['train'].S3Output.S3Uri"},
#         'S3DataDistributionType': 'FullyReplicated'}},
#       'ChannelName': 'train'},
#      {'DataSource': {'S3DataSource': {'S3DataType': 'S3Prefix',
#         'S3Uri': {'Get': "Steps.TF2Process.ProcessingOutputConfig.Outputs['test'].S3Output.S3Uri"},
#         'S3DataDistributionType': 'FullyReplicated'}},
#       'ChannelName': 'test'}],
#     'HyperParameters': {'epochs': '44',
#      'batch_size': '128',
#      'learning_rate': '0.0125',
#      'for_pipeline': '"true"',
#      'sagemaker_submit_directory': '"s3://sagemaker-us-west-2-867719205611/tf-2-workflow-train-2021-01-16-05-51-32-157/source/sourcedir.tar.gz"',
#      'sagemaker_program': '"train.py"',
#      'sagemaker_container_log_level': '20',
#      'sagemaker_job_name': '"tf-2-workflow-train-2021-01-16-05-51-32-157"',
#      'sagemaker_region': '"us-west-2"',
#      'model_dir': '"s3://sagemaker-us-west-2-867719205611/TF2WorkflowTrain/tf-2-workflow-train-2021-01-16-05-51-32-157/model"'},
#     'DebugHookConfig': {'S3OutputPath': 's3://sagemaker-us-west-2-867719205611/TF2WorkflowTrain',
#      'CollectionConfigurations': []}}},
#   {'Name': 'TF2WorkflowCreateModel',
#    'Type': 'Model',
#    'Arguments': {'ExecutionRoleArn': 'arn:aws:iam::867719205611:role/service-role/AmazonSageMaker-ExecutionRole-20210115T224947',
#     'PrimaryContainer': {'Image': '763104351884.dkr.ecr.us-west-2.amazonaws.com/tensorflow-inference:2.3.1-cpu',
#      'Environment': {},
#      'ModelDataUrl': {'Get': 'Steps.TF2WorkflowTrain.ModelArtifacts.S3ModelArtifacts'}}}},
#   {'Name': 'TF2WorkflowBatchScoring',
#    'Type': 'Processing',
#    'Arguments': {'ProcessingResources': {'ClusterConfig': {'InstanceType': {'Get': 'Parameters.BatchInstanceType'},
#       'InstanceCount': {'Get': 'Parameters.BatchInstanceCount'},
#       'VolumeSizeInGB': 30}},
#     'AppSpecification': {'ImageUri': '246618743249.dkr.ecr.us-west-2.amazonaws.com/sagemaker-scikit-learn:0.23-1-cpu-py3',
#      'ContainerEntrypoint': ['python3',
#       '/opt/ml/processing/input/code/batch-score.py']},
#     'RoleArn': 'arn:aws:iam::867719205611:role/service-role/AmazonSageMaker-ExecutionRole-20210115T224947',
#     'ProcessingInputs': [{'InputName': 'input-1',
#       'S3Input': {'S3Uri': {'Get': 'Steps.TF2WorkflowTrain.ModelArtifacts.S3ModelArtifacts'},
#        'LocalPath': '/opt/ml/processing/model',
#        'S3DataType': 'S3Prefix',
#        'S3InputMode': 'File',
#        'S3DataDistributionType': 'FullyReplicated',
#        'S3CompressionType': 'None'}},
#      {'InputName': 'input-2',
#       'S3Input': {'S3Uri': {'Get': "Steps.TF2Process.ProcessingOutputConfig.Outputs['test'].S3Output.S3Uri"},
#        'LocalPath': '/opt/ml/processing/test',
#        'S3DataType': 'S3Prefix',
#        'S3InputMode': 'File',
#        'S3DataDistributionType': 'FullyReplicated',
#        'S3CompressionType': 'None'}},
#      {'InputName': 'code',
#       'S3Input': {'S3Uri': 's3://sagemaker-us-west-2-867719205611/tf-2-workflow-batch-2021-01-16-05-51-32-810/input/code/batch-score.py',
#        'LocalPath': '/opt/ml/processing/input/code',
#        'S3DataType': 'S3Prefix',
#        'S3InputMode': 'File',
#        'S3DataDistributionType': 'FullyReplicated',
#        'S3CompressionType': 'None'}}],
#     'ProcessingOutputConfig': {'Outputs': [{'OutputName': 'batch',
#        'S3Output': {'S3Uri': 's3://sagemaker-us-west-2-867719205611/tf-2-workflow-batch-2021-01-16-05-51-32-810/output/batch',
#         'LocalPath': '/opt/ml/processing/batch',
#         'S3UploadMode': 'EndOfJob'}}]}}}]}

# %%
pipeline.upsert(role_arn=role)
execution = pipeline.start()

# %%
execution.describe()
# Out:
# {'PipelineArn': 'arn:aws:sagemaker:us-west-2:867719205611:pipeline/tf2workflow',
#  'PipelineExecutionArn': 'arn:aws:sagemaker:us-west-2:867719205611:pipeline/tf2workflow/execution/y9651a2m5kif',
#  'PipelineExecutionDisplayName': 'execution-1610776427863',
#  'PipelineExecutionStatus': 'Executing',
#  'CreationTime': datetime.datetime(2021, 1, 16, 5, 53, 47, 715000, tzinfo=tzlocal()),
#  'LastModifiedTime': datetime.datetime(2021, 1, 16, 5, 53, 47, 715000, tzinfo=tzlocal()),
#  'CreatedBy': {},
#  'LastModifiedBy': {},
#  'ResponseMetadata': {'RequestId': 'c7c061b9-b3a4-4079-972f-da17921a57a4',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'c7c061b9-b3a4-4079-972f-da17921a57a4',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '387',
#    'date': 'Sat, 16 Jan 2021 05:53:53 GMT'},
#   'RetryAttempts': 0}}

# %%
execution.wait()
execution.list_steps()
# Out:
# [{'StepName': 'TF2WorkflowCreateModel',
#   'StartTime': datetime.datetime(2021, 1, 16, 6, 0, 51, 127000, tzinfo=tzlocal()),
#   'EndTime': datetime.datetime(2021, 1, 16, 6, 0, 51, 951000, tzinfo=tzlocal()),
#   'StepStatus': 'Succeeded',
#   'Metadata': {'Model': {'Arn': 'arn:aws:sagemaker:us-west-2:867719205611:model/pipelines-y9651a2m5kif-tf2workflowcreatemod-rgdki0vd3b'}}},
#  {'StepName': 'TF2WorkflowBatchScoring',
#   'StartTime': datetime.datetime(2021, 1, 16, 6, 0, 51, 111000, tzinfo=tzlocal()),
#   'EndTime': datetime.datetime(2021, 1, 16, 6, 5, 30, 931000, tzinfo=tzlocal()),
#   'StepStatus': 'Succeeded',
#   'Metadata': {'ProcessingJob': {'Arn': 'arn:aws:sagemaker:us-west-2:867719205611:processing-job/pipelines-y9651a2m5kif-tf2workflowbatchscor-86bae7jmtv'}}},
#  {'StepName': 'TF2WorkflowTrain',
#   'StartTime': datetime.datetime(2021, 1, 16, 5, 58, 0, 988000, tzinfo=tzlocal()),
#   'EndTime': datetime.datetime(2021, 1, 16, 6, 0, 50, 890000, tzinfo=tzlocal()),
#   'StepStatus': 'Succeeded',
#   'Metadata': {'TrainingJob': {'Arn': 'arn:aws:sagemaker:us-west-2:867719205611:training-job/pipelines-y9651a2m5kif-tf2workflowtrain-lahwzcjrok'}}},
#  {'StepName': 'TF2Process',
#   'StartTime': datetime.datetime(2021, 1, 16, 5, 53, 48, 383000, tzinfo=tzlocal()),
#   'EndTime': datetime.datetime(2021, 1, 16, 5, 57, 54, 860000, tzinfo=tzlocal()),
#   'StepStatus': 'Succeeded',
#   'Metadata': {'ProcessingJob': {'Arn': 'arn:aws:sagemaker:us-west-2:867719205611:processing-job/pipelines-y9651a2m5kif-tf2process-rrmq439eqs'}}}]

# %%
report_path = f"{step_batch.outputs[0].destination}/score-report.txt"
# !aws s3 cp {report_path} ./score-report.txt && cat score-report.txt
# Out:
# download: s3://sagemaker-us-west-2-867719205611/tf-2-workflow-batch-2021-01-16-05-51-32-810/output/batch/score-report.txt to ./score-report.txt
# Test MSE : 25.488441467285156
